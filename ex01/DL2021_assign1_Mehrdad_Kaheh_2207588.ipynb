# %% [markdown]
# Deep Learning assignment 1: Assignment 1
#
# Designed by Shuzhou Sun (shuzhou.sun@oulu.fi)

# %% [markdown]
# ## Outline (15 points)
# #### In this assignment, you will learn:
# * How to generate random data using Pytorch.
# * How to build your own Pytorch model for simple regression problem on the generated data.
# * Training the model with gradient descent algorithm in Pytorch.
#
# #### Environment
# Python 3 + Pytorch (>=1.3).<br>
# Other libraries should be installed correctly such as numpy, matplotlib, *etc*., according to the dependencies of the assignment. <br>
# If you haven’t installed Pytorch and Jupyter notebook in your computer, an alternative environment to finish the assignment is CSC notebook: [`https://notebooks.csc.fi/`](https://notebooks.csc.fi/) -> log in with HaKa using your university account -> Jupyter Machine Learning
#
# We will give 2 weeks for each assignment and more for the final project. So it may happen where the new assignment is published before the deadline of the previous assignment.
#
# #### Database
# * Randomly synthesized data.
#
# #### Hints
# * To find the place where you have to insert your solution, hit Crtl + F and search for **TODO:** . You are not supposed to modify the codes from other parts.
# * Be careful with the shape of the weights, gradient, .. of your tensor in your implementation. Double check and make sure the shapes fit for computation, especially matrix multiplication.

# %% [markdown]
# ## Part 1. Generate training and testing data using Pytorch
# Suppose we observe a real-valued input variable $x$ and we wish to use this observation to predict the value of a real-valued target variable $y$. For the present purposes, it is instructive to consider an artificial example using synthetically generated data because we then know the precise process that generated the data for comparison against any learned model.
#
# We therefore generate our training data which consists of 1000 pairs of $\{x_i, y_i\}$ where $\{x_i\}$ are generated uniformly, and the corresponding target values $\{y_i\}$ are obtained by first computing the corresponding values of a pre-defined function and then adding random noise with a Gaussian distribution having standard deviation 0.5.
# \begin{align*}
# y_i = 2.4 * x_i^{2} - 1.9 * x_i + 0.6 + \varepsilon, \varepsilon\sim \mathcal{N}(0,\,0.5^{2})
# \end{align*}
#
# The testing data is created the same way as training data **but without noise**, where the number of pairs is 100, in order to give a quantitative evaluation of the model to be trained.
#
# Please create the required training and testing data below and plot them. You could use [`torch.randn()`](https://pytorch.org/docs/stable/generated/torch.rand.html#torch.rand) to create the data and matplotlib.pyplot to show them.

# %% [markdown]
# Here, I would like to warm you up with a simple example using the function: $y = x^2 + \varepsilon, \varepsilon\sim \mathcal{N}(0,\,0.2^{2})$

# %%
import torch
import matplotlib.pyplot as plt

x = torch.randn(100)
y = torch.pow(x, 2) + torch.randn(100) * 0.2

plt.figure(figsize=(10, 5))
plt.rcParams.update({'font.size': 10})
plt.plot(x, y, marker='o', linestyle='none', markersize=5)
plt.show()

# %%
# TODO: (3 points, details are given below): 
# generate 1000 training data pairs and 100 testing data pairs according to the above description.

# generate training data (1 point)
x_train = torch.randn(1000)
y_train = 2.4 * torch.pow(x_train, 2) - 1.9 * x_train + 0.6 +  torch.randn(1000) * 0.5

# generate testing data (1 point)
x_test = torch.randn(100)
y_test = 2.4 * torch.pow(x_test, 2) - 1.9 * x_test + 0.6

# draw the data in a single figure (using two different showing styles) (1 point)
plt.figure(figsize=(40,20))
plt.rcParams.update({'font.size': 30})
plt.plot(x_train, y_train, marker='o', linestyle='none') 
plt.plot(x_test, y_test, marker='o', color='r', linestyle='none', markersize=15) 

plt.show()
plt.rcParams.update(plt.rcParamsDefault)

# %% [markdown]
# The plot figure should be like this. However, you could have your own showing styles.

# %% [markdown]
# ## Part 2. Solving the regression problem in Pytorch using Gradient Descent Algorithm
#
# ### 2.1 Data
# Congratulations if you generate the data correctly! However, to make sure all of you use the same data, we have generated it in advance.

# %%
data = torch.load('dataset.pt')
x_train = data['x_train']
y_train = data['y_train']
x_test = data['x_test']
y_test = data['y_test']

# %% [markdown]
# ### 2.2 Model
# In this part, you will define your own model class. To do that, you have to remember the following rules:
# 1. The model class should be inherited from [`nn.Module`](https://pytorch.org/docs/stable/generated/torch.nn.Module.html#torch.nn.Module);
# 2. Re-write the **\_\_init\_\_** function and the **forward** function;
# 3. In the **\_\_init\_\_** function, you should always call the parent's **\_\_init\_\_** function first.
#
# To make it simpler, suppose we have already known the main structure of the function that generated the data:
# \begin{align*}
# y = a * x^2 + b*x + c.
# \end{align*}
#
# Therefore, in the model, we need to set 3 parameters: $a$, $b$ and $c$.

# %%
# TODO (3.5 points, details are given below)
import torch.nn as nn

# define a class (0.5) + write the __init__ function (1.5 point) + write the forward function (1.5 points)
class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.a = nn.Parameter(torch.rand(1))
        self.b = nn.Parameter(torch.rand(1))
        self.c = nn.Parameter(torch.rand(1))

    def forward(self, data):
        f = self.a * data**2 + self.b * data + self.c
        return f

# %% [markdown]
# ### 2.3 Training
# Here, you will train your model based on the training data and evaluate the model on testing data.
# 1. Set proper number of iterations and learning rate.
# 2. Remember to use a proper optimizer (you may have many choices: Adam, SGD, RMSprop, ... please find the detailed information in https://pytorch.org/docs/stable/optim.html and know how to use them).
# 3. In order to train the model, a loss function should be defined:
# \begin{align*}
# loss = \frac{1}{N}\sum_{i=1}^{N}|f_i - y_i|,
# \end{align*}
# where, $f_i$ is the output of the model and $N$ is the number of training data pairs.
# 4. The model must be trained only using training data.
# 5. Remember to clear the old gradients of parameters before a new backward propagation.
# 6. In every certain number of iterations, print the values of the parameters, the training loss, and the testing loss.
# 7. Meanwhile, please track the training loss and the testing loss in each iteration. Once the training is done, the curves of losses should be plotted (two curves are drawn in the same figure, where x axis indicates iterations and y axis indicates the losses).
# 8. Lastly, draw all the training data, testing data and the curve of the trained model in the same figure (use different showing styles to distinguish them).

# %%
# TODO: (8.5 points, details are given below)

# Make an instance of the model class (0.5 point)
model = Model()

# create an optimizer, set a workable learing rate (0.5 point + 0.5 point)
optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)

training_losses = []
testing_losses = []
n_itr = 10000

for i in range(n_itr):
    # Train
    model.train() # change model to train mode
    # forward propagation
    # calculate the output of model (0.5 point)
    f = model(x_train)
    
    # calculate loss according to the above equation (0.5 point)
    loss_train = torch.abs(f - y_train).mean()
    
    # backward propagation 
    # clear old gradients (0.5)
    optimizer.zero_grad()
    loss_train.backward()
    training_losses.append(loss_train.item())
    
    # calculate gradients of parameters (1 point)
    
    # gradient descent algorithm (1 point)
    optimizer.step()
    
    # Evaluate, calculate the testing loss (0.5 point)
    model.eval() # change model to eval mode
    f = model(x_test)
    loss_test = torch.abs(f - y_test).mean()
    testing_losses.append(loss_test.item())
    
    # print intermediate results in every certain iterations (1 point)
    if i % 100 == 0:
        print('Iteration: %i | a: %f b: %f | c: %f | Training loss: %f | Testing loss: %f' % (i+1, model.a.data, model.b.data, model.c.data, loss_train, loss_test))
# Out:
# Iteration: 1 | a: 0.385734 b: 0.170521 | c: 0.703272 | Training loss: 16.768564 | Testing loss: 17.037815
# Iteration: 101 | a: 0.485718 b: 0.069142 | c: 0.802466 | Training loss: 15.847748 | Testing loss: 16.100502
# Iteration: 201 | a: 0.585665 b: -0.031585 | c: 0.900291 | Training loss: 14.931861 | Testing loss: 15.167184
# Iteration: 301 | a: 0.685601 b: -0.138862 | c: 0.997621 | Training loss: 14.017961 | Testing loss: 14.237002
# Iteration: 401 | a: 0.785530 b: -0.249410 | c: 1.094588 | Training loss: 13.105612 | Testing loss: 13.310564
# Iteration: 501 | a: 0.885392 b: -0.356749 | c: 1.189688 | Training loss: 12.198734 | Testing loss: 12.388968
# Iteration: 601 | a: 0.985193 b: -0.476661 | c: 1.283470 | Training loss: 11.295307 | Testing loss: 11.472733
# Iteration: 701 | a: 1.084937 b: -0.577104 | c: 1.375718 | Training loss: 10.397962 | Testing loss: 10.562966
# Iteration: 801 | a: 1.184571 b: -0.646821 | c: 1.465330 | Training loss: 9.509429 | Testing loss: 9.660742
# Iteration: 901 | a: 1.284067 b: -0.696546 | c: 1.552726 | Training loss: 8.629006 | Testing loss: 8.767239
# Iteration: 1001 | a: 1.383317 b: -0.688165 | c: 1.637800 | Training loss: 7.758258 | Testing loss: 7.882871
# Iteration: 1101 | a: 1.482191 b: -0.664287 | c: 1.719360 | Training loss: 6.900689 | Testing loss: 7.010235
# Iteration: 1201 | a: 1.580727 b: -0.680752 | c: 1.798010 | Training loss: 6.054969 | Testing loss: 6.149973
# Iteration: 1301 | a: 1.678724 b: -0.714488 | c: 1.872673 | Training loss: 5.225589 | Testing loss: 5.305919
# Iteration: 1401 | a: 1.775820 b: -0.716222 | c: 1.941437 | Training loss: 4.420513 | Testing loss: 4.484163
# Iteration: 1501 | a: 1.871933 b: -0.725237 | c: 2.004587 | Training loss: 3.640824 | Testing loss: 3.689843
# Iteration: 1601 | a: 1.966379 b: -0.692755 | c: 2.059619 | Training loss: 2.899093 | Testing loss: 2.934053
# Iteration: 1701 | a: 2.057563 b: -0.681799 | c: 2.101259 | Training loss: 2.222289 | Testing loss: 2.240002
# Iteration: 1801 | a: 2.142447 b: -0.691264 | c: 2.122070 | Training loss: 1.651548 | Testing loss: 1.644600
# Iteration: 1901 | a: 2.218365 b: -0.702164 | c: 2.117035 | Training loss: 1.207145 | Testing loss: 1.184460
# Iteration: 2001 | a: 2.273675 b: -0.689965 | c: 2.072933 | Training loss: 0.968512 | Testing loss: 0.929076
# Iteration: 2101 | a: 2.298463 b: -0.698672 | c: 1.986376 | Training loss: 0.887542 | Testing loss: 0.829146
# Iteration: 2201 | a: 2.309895 b: -0.694320 | c: 1.885836 | Training loss: 0.829972 | Testing loss: 0.762748
# Iteration: 2301 | a: 2.316975 b: -0.694532 | c: 1.782655 | Training loss: 0.775360 | Testing loss: 0.701760
# Iteration: 2401 | a: 2.324015 b: -0.692737 | c: 1.682361 | Training loss: 0.723787 | Testing loss: 0.642419
# Iteration: 2501 | a: 2.330421 b: -0.692828 | c: 1.585881 | Training loss: 0.676593 | Testing loss: 0.585684
# Iteration: 2601 | a: 2.336768 b: -0.693393 | c: 1.492553 | Training loss: 0.632670 | Testing loss: 0.530566
# Iteration: 2701 | a: 2.342682 b: -0.697748 | c: 1.402679 | Training loss: 0.592559 | Testing loss: 0.477688
# Iteration: 2801 | a: 2.348665 b: -0.696698 | c: 1.317760 | Training loss: 0.557101 | Testing loss: 0.427280
# Iteration: 2901 | a: 2.353946 b: -0.693763 | c: 1.238285 | Training loss: 0.526830 | Testing loss: 0.380856
# Iteration: 3001 | a: 2.360136 b: -0.697905 | c: 1.164618 | Training loss: 0.500773 | Testing loss: 0.335292
# Iteration: 3101 | a: 2.365022 b: -0.695814 | c: 1.093339 | Training loss: 0.477540 | Testing loss: 0.293337
# Iteration: 3201 | a: 2.369413 b: -0.693848 | c: 1.026278 | Training loss: 0.457658 | Testing loss: 0.254380
# Iteration: 3301 | a: 2.373851 b: -0.696544 | c: 0.964512 | Training loss: 0.441213 | Testing loss: 0.217242
# Iteration: 3401 | a: 2.377572 b: -0.696061 | c: 0.908736 | Training loss: 0.428346 | Testing loss: 0.184599
# Iteration: 3501 | a: 2.380824 b: -0.695044 | c: 0.860753 | Training loss: 0.419219 | Testing loss: 0.156599
# Iteration: 3601 | a: 2.383703 b: -0.694787 | c: 0.819110 | Training loss: 0.412592 | Testing loss: 0.132160
# Iteration: 3701 | a: 2.386078 b: -0.695630 | c: 0.781082 | Training loss: 0.407331 | Testing loss: 0.110184
# Iteration: 3801 | a: 2.388695 b: -0.694302 | c: 0.746555 | Training loss: 0.403123 | Testing loss: 0.089892
# Iteration: 3901 | a: 2.390893 b: -0.693745 | c: 0.716050 | Training loss: 0.400002 | Testing loss: 0.072271
# Iteration: 4001 | a: 2.392473 b: -0.692344 | c: 0.690077 | Training loss: 0.397875 | Testing loss: 0.058854
# Iteration: 4101 | a: 2.394083 b: -0.691765 | c: 0.666930 | Training loss: 0.396249 | Testing loss: 0.046662
# Iteration: 4201 | a: 2.395013 b: -0.691707 | c: 0.648054 | Training loss: 0.395241 | Testing loss: 0.038037
# Iteration: 4301 | a: 2.396025 b: -0.691507 | c: 0.635924 | Training loss: 0.394830 | Testing loss: 0.031953
# Iteration: 4401 | a: 2.396636 b: -0.692195 | c: 0.627238 | Training loss: 0.394632 | Testing loss: 0.027134
# Iteration: 4501 | a: 2.397050 b: -0.692698 | c: 0.620101 | Training loss: 0.394506 | Testing loss: 0.023756
# Iteration: 4601 | a: 2.397319 b: -0.692877 | c: 0.616145 | Training loss: 0.394469 | Testing loss: 0.022025
# Iteration: 4701 | a: 2.397419 b: -0.692782 | c: 0.613807 | Training loss: 0.394457 | Testing loss: 0.021587
# Iteration: 4801 | a: 2.397538 b: -0.692851 | c: 0.612126 | Training loss: 0.394451 | Testing loss: 0.020929
# Iteration: 4901 | a: 2.397561 b: -0.692729 | c: 0.611207 | Training loss: 0.394450 | Testing loss: 0.020988
# Iteration: 5001 | a: 2.397562 b: -0.692667 | c: 0.610811 | Training loss: 0.394450 | Testing loss: 0.021067
# Iteration: 5101 | a: 2.397593 b: -0.692802 | c: 0.610853 | Training loss: 0.394449 | Testing loss: 0.020739
# Iteration: 5201 | a: 2.397588 b: -0.692940 | c: 0.610858 | Training loss: 0.394448 | Testing loss: 0.020557
# Iteration: 5301 | a: 2.397582 b: -0.692962 | c: 0.610851 | Training loss: 0.394448 | Testing loss: 0.020546
# Iteration: 5401 | a: 2.397568 b: -0.693056 | c: 0.610821 | Training loss: 0.394449 | Testing loss: 0.020466
# Iteration: 5501 | a: 2.397595 b: -0.693132 | c: 0.610842 | Training loss: 0.394450 | Testing loss: 0.020240
# Iteration: 5601 | a: 2.397584 b: -0.692890 | c: 0.610842 | Training loss: 0.394448 | Testing loss: 0.020646
# Iteration: 5701 | a: 2.397573 b: -0.693036 | c: 0.610817 | Training loss: 0.394449 | Testing loss: 0.020469
# Iteration: 5801 | a: 2.397591 b: -0.692790 | c: 0.610855 | Training loss: 0.394450 | Testing loss: 0.020766
# Iteration: 5901 | a: 2.397591 b: -0.692751 | c: 0.610816 | Training loss: 0.394448 | Testing loss: 0.020826
# Iteration: 6001 | a: 2.397573 b: -0.692777 | c: 0.610840 | Training loss: 0.394450 | Testing loss: 0.020857
# Iteration: 6101 | a: 2.397583 b: -0.692904 | c: 0.610847 | Training loss: 0.394448 | Testing loss: 0.020627
# Iteration: 6201 | a: 2.397573 b: -0.692794 | c: 0.610845 | Training loss: 0.394449 | Testing loss: 0.020834
# Iteration: 6301 | a: 2.397571 b: -0.692841 | c: 0.610842 | Training loss: 0.394449 | Testing loss: 0.020771
# Iteration: 6401 | a: 2.397593 b: -0.692964 | c: 0.610818 | Training loss: 0.394449 | Testing loss: 0.020495
# Iteration: 6501 | a: 2.397616 b: -0.692996 | c: 0.610825 | Training loss: 0.394450 | Testing loss: 0.020357
# Iteration: 6601 | a: 2.397581 b: -0.692992 | c: 0.610836 | Training loss: 0.394449 | Testing loss: 0.020504
# Iteration: 6701 | a: 2.397571 b: -0.692896 | c: 0.610848 | Training loss: 0.394448 | Testing loss: 0.020687
# Iteration: 6801 | a: 2.397572 b: -0.692882 | c: 0.610857 | Training loss: 0.394449 | Testing loss: 0.020707
# Iteration: 6901 | a: 2.397595 b: -0.692922 | c: 0.610852 | Training loss: 0.394449 | Testing loss: 0.020553
# Iteration: 7001 | a: 2.397562 b: -0.693199 | c: 0.610820 | Training loss: 0.394450 | Testing loss: 0.020290
# Iteration: 7101 | a: 2.397586 b: -0.692975 | c: 0.610830 | Training loss: 0.394449 | Testing loss: 0.020509
# Iteration: 7201 | a: 2.397571 b: -0.692911 | c: 0.610802 | Training loss: 0.394448 | Testing loss: 0.020665
# Iteration: 7301 | a: 2.397593 b: -0.692944 | c: 0.610854 | Training loss: 0.394449 | Testing loss: 0.020529
# Iteration: 7401 | a: 2.397589 b: -0.692826 | c: 0.610824 | Training loss: 0.394449 | Testing loss: 0.020719
# Iteration: 7501 | a: 2.397554 b: -0.693066 | c: 0.610788 | Training loss: 0.394450 | Testing loss: 0.020513
# Iteration: 7601 | a: 2.397635 b: -0.692764 | c: 0.610852 | Training loss: 0.394450 | Testing loss: 0.020646
# Iteration: 7701 | a: 2.397552 b: -0.692979 | c: 0.610818 | Training loss: 0.394450 | Testing loss: 0.020647
# Iteration: 7801 | a: 2.397602 b: -0.692951 | c: 0.610864 | Training loss: 0.394449 | Testing loss: 0.020481
# Iteration: 7901 | a: 2.397580 b: -0.692887 | c: 0.610803 | Training loss: 0.394448 | Testing loss: 0.020667
# Iteration: 8001 | a: 2.397591 b: -0.692927 | c: 0.610807 | Training loss: 0.394450 | Testing loss: 0.020558
# Iteration: 8101 | a: 2.397587 b: -0.692752 | c: 0.610850 | Training loss: 0.394450 | Testing loss: 0.020840
# Iteration: 8201 | a: 2.397581 b: -0.692921 | c: 0.610745 | Training loss: 0.394449 | Testing loss: 0.020608
# Iteration: 8301 | a: 2.397604 b: -0.692810 | c: 0.610861 | Training loss: 0.394449 | Testing loss: 0.020687
# Iteration: 8401 | a: 2.397583 b: -0.693014 | c: 0.610850 | Training loss: 0.394449 | Testing loss: 0.020465
# Iteration: 8501 | a: 2.397572 b: -0.692837 | c: 0.610774 | Training loss: 0.394448 | Testing loss: 0.020771
# Iteration: 8601 | a: 2.397598 b: -0.692959 | c: 0.610861 | Training loss: 0.394449 | Testing loss: 0.020487
# Iteration: 8701 | a: 2.397579 b: -0.692873 | c: 0.610848 | Training loss: 0.394448 | Testing loss: 0.020690
# Iteration: 8801 | a: 2.397607 b: -0.692928 | c: 0.610808 | Training loss: 0.394449 | Testing loss: 0.020493
# Iteration: 8901 | a: 2.397546 b: -0.693096 | c: 0.610733 | Training loss: 0.394450 | Testing loss: 0.020505
# Iteration: 9001 | a: 2.397636 b: -0.692805 | c: 0.610810 | Training loss: 0.394450 | Testing loss: 0.020574
# Iteration: 9101 | a: 2.397555 b: -0.693145 | c: 0.610756 | Training loss: 0.394450 | Testing loss: 0.020397
# Iteration: 9201 | a: 2.397577 b: -0.693215 | c: 0.610765 | Training loss: 0.394450 | Testing loss: 0.020201
# Iteration: 9301 | a: 2.397624 b: -0.692663 | c: 0.610774 | Training loss: 0.394450 | Testing loss: 0.020840
# Iteration: 9401 | a: 2.397583 b: -0.692586 | c: 0.610793 | Training loss: 0.394451 | Testing loss: 0.021114
# Iteration: 9501 | a: 2.397593 b: -0.692953 | c: 0.610817 | Training loss: 0.394449 | Testing loss: 0.020516
# Iteration: 9601 | a: 2.397533 b: -0.692661 | c: 0.610832 | Training loss: 0.394451 | Testing loss: 0.021194
# Iteration: 9701 | a: 2.397562 b: -0.692794 | c: 0.610754 | Training loss: 0.394449 | Testing loss: 0.020875
# Iteration: 9801 | a: 2.397522 b: -0.692842 | c: 0.610773 | Training loss: 0.394451 | Testing loss: 0.020969
# Iteration: 9901 | a: 2.397584 b: -0.693090 | c: 0.610838 | Training loss: 0.394448 | Testing loss: 0.020347

# %% [markdown]
# The output should be like this:

# %%
# Out:
# Iteration: 0001 | a: 0.378213 b: 0.057480 | c: 0.544852 | Training loss: 16.970774 | Testing loss: 17.244152
# Iteration: 0101 | a: 0.478207 b: -0.044622 | c: 0.644401 | Training loss: 16.045330 | Testing loss: 16.300116
# Iteration: 0201 | a: 0.578153 b: -0.149410 | c: 0.742144 | Training loss: 15.125428 | Testing loss: 15.361938
# Iteration: 0301 | a: 0.678092 b: -0.235641 | c: 0.839007 | Training loss: 14.209342 | Testing loss: 14.428289
# Iteration: 0401 | a: 0.778019 b: -0.344649 | c: 0.935311 | Training loss: 13.295006 | Testing loss: 13.497882
# Iteration: 0501 | a: 0.877906 b: -0.459263 | c: 1.030640 | Training loss: 12.384056 | Testing loss: 12.572121
# Iteration: 0601 | a: 0.977755 b: -0.564160 | c: 1.125009 | Training loss: 11.476820 | Testing loss: 11.650989
# Iteration: 0701 | a: 1.077571 b: -0.660536 | c: 1.218309 | Training loss: 10.573497 | Testing loss: 10.736301
# Iteration: 0801 | a: 1.177281 b: -0.730919 | c: 1.308933 | Training loss: 9.678444 | Testing loss: 9.828588
# Iteration: 0901 | a: 1.276832 b: -0.772414 | c: 1.396265 | Training loss: 8.792999 | Testing loss: 8.930044
# Iteration: 1001 | a: 1.376173 b: -0.749734 | c: 1.481448 | Training loss: 7.916358 | Testing loss: 8.038906
# Iteration: 1101 | a: 1.475255 b: -0.680943 | c: 1.563866 | Training loss: 7.049600 | Testing loss: 7.158081
# Iteration: 1201 | a: 1.573972 b: -0.673486 | c: 1.643114 | Training loss: 6.195866 | Testing loss: 6.289223
# Iteration: 1301 | a: 1.672306 b: -0.696591 | c: 1.719255 | Training loss: 5.355173 | Testing loss: 5.433847
# Iteration: 1401 | a: 1.769862 b: -0.706790 | c: 1.790246 | Training loss: 4.535918 | Testing loss: 4.598596
# Iteration: 1501 | a: 1.866489 b: -0.729269 | c: 1.855480 | Training loss: 3.741709 | Testing loss: 3.788871
# Iteration: 1601 | a: 1.961796 b: -0.691353 | c: 1.913664 | Training loss: 2.979134 | Testing loss: 3.012475
# Iteration: 1701 | a: 2.054333 b: -0.682386 | c: 1.960254 | Training loss: 2.274036 | Testing loss: 2.291049
# Iteration: 1801 | a: 2.141441 b: -0.690531 | c: 1.988528 | Training loss: 1.665787 | Testing loss: 1.659338
# Iteration: 1901 | a: 2.219862 b: -0.719605 | c: 1.992251 | Training loss: 1.186962 | Testing loss: 1.161804
# Iteration: 2001 | a: 2.279258 b: -0.688942 | c: 1.958903 | Training loss: 0.914218 | Testing loss: 0.871477
# Iteration: 2101 | a: 2.305370 b: -0.695131 | c: 1.879937 | Training loss: 0.830677 | Testing loss: 0.767407
# Iteration: 2201 | a: 2.316334 b: -0.692107 | c: 1.785081 | Training loss: 0.776822 | Testing loss: 0.704005
# Iteration: 2301 | a: 2.323483 b: -0.693103 | c: 1.688999 | Training loss: 0.727138 | Testing loss: 0.646417
# Iteration: 2401 | a: 2.329696 b: -0.692765 | c: 1.595672 | Training loss: 0.681281 | Testing loss: 0.591545
# Iteration: 2501 | a: 2.335836 b: -0.692977 | c: 1.505034 | Training loss: 0.638437 | Testing loss: 0.538073
# Iteration: 2601 | a: 2.341743 b: -0.697352 | c: 1.417229 | Training loss: 0.598850 | Testing loss: 0.486185
# Iteration: 2701 | a: 2.347537 b: -0.696702 | c: 1.333668 | Training loss: 0.563511 | Testing loss: 0.436735
# Iteration: 2801 | a: 2.352799 b: -0.695518 | c: 1.255068 | Training loss: 0.533000 | Testing loss: 0.390585
# Iteration: 2901 | a: 2.358613 b: -0.696622 | c: 1.182110 | Training loss: 0.506851 | Testing loss: 0.346153
# Iteration: 3001 | a: 2.363690 b: -0.696769 | c: 1.111505 | Training loss: 0.483284 | Testing loss: 0.304113
# Iteration: 3101 | a: 2.368138 b: -0.694929 | c: 1.044406 | Training loss: 0.462804 | Testing loss: 0.264955
# Iteration: 3201 | a: 2.372543 b: -0.695660 | c: 0.982276 | Training loss: 0.445701 | Testing loss: 0.227989
# Iteration: 3301 | a: 2.376631 b: -0.696117 | c: 0.925672 | Training loss: 0.432013 | Testing loss: 0.194223
# Iteration: 3401 | a: 2.379744 b: -0.694824 | c: 0.875635 | Training loss: 0.421852 | Testing loss: 0.165496
# Iteration: 3501 | a: 2.382679 b: -0.696120 | c: 0.832894 | Training loss: 0.414681 | Testing loss: 0.140125
# Iteration: 3601 | a: 2.385155 b: -0.695597 | c: 0.794377 | Training loss: 0.409124 | Testing loss: 0.117977
# Iteration: 3701 | a: 2.387550 b: -0.694103 | c: 0.758711 | Training loss: 0.404545 | Testing loss: 0.097732
# Iteration: 3801 | a: 2.390200 b: -0.694344 | c: 0.727120 | Training loss: 0.401047 | Testing loss: 0.078232
# Iteration: 3901 | a: 2.391797 b: -0.693077 | c: 0.699616 | Training loss: 0.398604 | Testing loss: 0.063791
# Iteration: 4001 | a: 2.393426 b: -0.691920 | c: 0.675982 | Training loss: 0.396857 | Testing loss: 0.051475
# Iteration: 4101 | a: 2.394700 b: -0.691778 | c: 0.654932 | Training loss: 0.395555 | Testing loss: 0.040935
# Iteration: 4201 | a: 2.395584 b: -0.691233 | c: 0.640071 | Training loss: 0.394941 | Testing loss: 0.034666
# Iteration: 4301 | a: 2.396442 b: -0.692462 | c: 0.630623 | Training loss: 0.394696 | Testing loss: 0.028128
# Iteration: 4401 | a: 2.396875 b: -0.692659 | c: 0.623074 | Training loss: 0.394553 | Testing loss: 0.024897
# Iteration: 4501 | a: 2.397228 b: -0.692885 | c: 0.617565 | Training loss: 0.394479 | Testing loss: 0.022508
# Iteration: 4601 | a: 2.397394 b: -0.692975 | c: 0.614708 | Training loss: 0.394460 | Testing loss: 0.021467
# Iteration: 4701 | a: 2.397483 b: -0.693087 | c: 0.612858 | Training loss: 0.394453 | Testing loss: 0.020830
# Iteration: 4801 | a: 2.397558 b: -0.693020 | c: 0.611630 | Training loss: 0.394450 | Testing loss: 0.020576
# Iteration: 4901 | a: 2.397568 b: -0.692550 | c: 0.610787 | Training loss: 0.394451 | Testing loss: 0.021226
# Iteration: 5001 | a: 2.397583 b: -0.692915 | c: 0.610834 | Training loss: 0.394448 | Testing loss: 0.020613
# Iteration: 5101 | a: 2.397614 b: -0.692945 | c: 0.610848 | Training loss: 0.394449 | Testing loss: 0.020442
# Iteration: 5201 | a: 2.397594 b: -0.692873 | c: 0.610854 | Training loss: 0.394449 | Testing loss: 0.020629
# Iteration: 5301 | a: 2.397580 b: -0.692845 | c: 0.610848 | Training loss: 0.394449 | Testing loss: 0.020730
# Iteration: 5401 | a: 2.397584 b: -0.692932 | c: 0.610848 | Training loss: 0.394448 | Testing loss: 0.020583
# Iteration: 5501 | a: 2.397584 b: -0.692958 | c: 0.610847 | Training loss: 0.394449 | Testing loss: 0.020542
# Iteration: 5601 | a: 2.397579 b: -0.692766 | c: 0.610842 | Training loss: 0.394448 | Testing loss: 0.020850
# Iteration: 5701 | a: 2.397595 b: -0.692945 | c: 0.610843 | Training loss: 0.394448 | Testing loss: 0.020517
# Iteration: 5801 | a: 2.397585 b: -0.692853 | c: 0.610853 | Training loss: 0.394448 | Testing loss: 0.020695
# Iteration: 5901 | a: 2.397579 b: -0.692984 | c: 0.610841 | Training loss: 0.394449 | Testing loss: 0.020526
# Iteration: 6001 | a: 2.397576 b: -0.692803 | c: 0.610821 | Training loss: 0.394449 | Testing loss: 0.020806
# Iteration: 6101 | a: 2.397580 b: -0.692835 | c: 0.610842 | Training loss: 0.394449 | Testing loss: 0.020741
# Iteration: 6201 | a: 2.397590 b: -0.692837 | c: 0.610863 | Training loss: 0.394449 | Testing loss: 0.020701
# Iteration: 6301 | a: 2.397583 b: -0.693043 | c: 0.610843 | Training loss: 0.394449 | Testing loss: 0.020419
# Iteration: 6401 | a: 2.397590 b: -0.692827 | c: 0.610857 | Training loss: 0.394448 | Testing loss: 0.020714
# Iteration: 6501 | a: 2.397577 b: -0.692842 | c: 0.610822 | Training loss: 0.394449 | Testing loss: 0.020744
# Iteration: 6601 | a: 2.397561 b: -0.692934 | c: 0.610818 | Training loss: 0.394449 | Testing loss: 0.020674
# Iteration: 6701 | a: 2.397565 b: -0.692797 | c: 0.610812 | Training loss: 0.394449 | Testing loss: 0.020859
# Iteration: 6801 | a: 2.397582 b: -0.692968 | c: 0.610851 | Training loss: 0.394449 | Testing loss: 0.020538
# Iteration: 6901 | a: 2.397581 b: -0.693127 | c: 0.610827 | Training loss: 0.394451 | Testing loss: 0.020306
# Iteration: 7001 | a: 2.397564 b: -0.692898 | c: 0.610821 | Training loss: 0.394449 | Testing loss: 0.020713
# Iteration: 7101 | a: 2.397566 b: -0.692742 | c: 0.610835 | Training loss: 0.394449 | Testing loss: 0.020940
# Iteration: 7201 | a: 2.397555 b: -0.692885 | c: 0.610846 | Training loss: 0.394449 | Testing loss: 0.020768
# Iteration: 7301 | a: 2.397614 b: -0.692943 | c: 0.610854 | Training loss: 0.394449 | Testing loss: 0.020443
# Iteration: 7401 | a: 2.397640 b: -0.692696 | c: 0.610811 | Training loss: 0.394451 | Testing loss: 0.020732
# Iteration: 7501 | a: 2.397598 b: -0.692820 | c: 0.610856 | Training loss: 0.394449 | Testing loss: 0.020692
# Iteration: 7601 | a: 2.397592 b: -0.692676 | c: 0.610859 | Training loss: 0.394450 | Testing loss: 0.020943
# Iteration: 7701 | a: 2.397573 b: -0.692891 | c: 0.610848 | Training loss: 0.394449 | Testing loss: 0.020689
# Iteration: 7801 | a: 2.397592 b: -0.692970 | c: 0.610851 | Training loss: 0.394449 | Testing loss: 0.020494
# Iteration: 7901 | a: 2.397607 b: -0.692911 | c: 0.610779 | Training loss: 0.394450 | Testing loss: 0.020519
# Iteration: 8001 | a: 2.397580 b: -0.692926 | c: 0.610851 | Training loss: 0.394448 | Testing loss: 0.020608
# Iteration: 8101 | a: 2.397593 b: -0.693024 | c: 0.610818 | Training loss: 0.394449 | Testing loss: 0.020408
# Iteration: 8201 | a: 2.397599 b: -0.692988 | c: 0.610846 | Training loss: 0.394448 | Testing loss: 0.020436
# Iteration: 8301 | a: 2.397571 b: -0.692817 | c: 0.610849 | Training loss: 0.394449 | Testing loss: 0.020806
# Iteration: 8401 | a: 2.397544 b: -0.692859 | c: 0.610825 | Training loss: 0.394449 | Testing loss: 0.020852
# Iteration: 8501 | a: 2.397565 b: -0.692747 | c: 0.610852 | Training loss: 0.394449 | Testing loss: 0.020934
# Iteration: 8601 | a: 2.397567 b: -0.693032 | c: 0.610785 | Training loss: 0.394450 | Testing loss: 0.020501
# Iteration: 8701 | a: 2.397616 b: -0.692890 | c: 0.610813 | Training loss: 0.394449 | Testing loss: 0.020514
# Iteration: 8801 | a: 2.397573 b: -0.693077 | c: 0.610805 | Training loss: 0.394449 | Testing loss: 0.020414
# Iteration: 8901 | a: 2.397625 b: -0.692720 | c: 0.610824 | Training loss: 0.394450 | Testing loss: 0.020747
# Iteration: 9001 | a: 2.397551 b: -0.693042 | c: 0.610785 | Training loss: 0.394449 | Testing loss: 0.020559
# Iteration: 9101 | a: 2.397552 b: -0.692957 | c: 0.610832 | Training loss: 0.394449 | Testing loss: 0.020672
# Iteration: 9201 | a: 2.397615 b: -0.692914 | c: 0.610869 | Training loss: 0.394449 | Testing loss: 0.020485
# Iteration: 9301 | a: 2.397615 b: -0.692868 | c: 0.610811 | Training loss: 0.394449 | Testing loss: 0.020552
# Iteration: 9401 | a: 2.397583 b: -0.692649 | c: 0.610746 | Training loss: 0.394449 | Testing loss: 0.021013
# Iteration: 9501 | a: 2.397557 b: -0.692722 | c: 0.610811 | Training loss: 0.394449 | Testing loss: 0.021007
# Iteration: 9601 | a: 2.397592 b: -0.692685 | c: 0.610822 | Training loss: 0.394450 | Testing loss: 0.020927
# Iteration: 9701 | a: 2.397569 b: -0.692712 | c: 0.610768 | Training loss: 0.394451 | Testing loss: 0.020970
# Iteration: 9801 | a: 2.397645 b: -0.692770 | c: 0.610846 | Training loss: 0.394451 | Testing loss: 0.020597
# Iteration: 9901 | a: 2.397564 b: -0.693088 | c: 0.610755 | Training loss: 0.394450 | Testing loss: 0.020439

# %%
# plot the traing losses (0.5 point) and testing losses (0.5 point)
#print(testing_losses)

plt.plot(training_losses, label="train")
plt.plot(testing_losses, label="test")
plt.legend()
plt.show()

# %% [markdown]
# The curves should be like this:

# %%
# plot all the training data, testing data and the curve of function (1 point)

plt.figure(figsize=(40,20))
plt.rcParams.update({'font.size': 30})
plt.plot(x_train, y_train, marker='o', linestyle='none') 
plt.plot(x_test, y_test, marker='o', color='r', linestyle='none', markersize=15) 

plt.show()
plt.rcParams.update(plt.rcParamsDefault)

# %% [markdown]
# The figure should be like this:

# %%
# Out:
# done
